# %% [markdown]
# ## Functions

# %% [markdown]
# #### Built-in functions
# ```
# input and print
# ```

# %%
def tablemultiplication():
    #-----
    #display first 20 values of the multiplication table
    #input: ..
    #Output:...
    #-----
    n = 1
    while n <= 20:
        v = n * 8
        print(n, " x ", 8, " = ", v, sep = " ")
        n = n + 1

# %%
tablemultiplication()
# Out:
# 1  x  8  =  8
# 2  x  8  =  16
# 3  x  8  =  24
# 4  x  8  =  32
# 5  x  8  =  40
# 6  x  8  =  48
# 7  x  8  =  56
# 8  x  8  =  64
# 9  x  8  =  72
# 10  x  8  =  80
# 11  x  8  =  88
# 12  x  8  =  96
# 13  x  8  =  104
# 14  x  8  =  112
# 15  x  8  =  120
# 16  x  8  =  128
# 17  x  8  =  136
# 18  x  8  =  144
# 19  x  8  =  152
# 20  x  8  =  160

# %%
def multiplication_table():
    print(f"multiplication table for {n}:")
    print(" = " * 25)
    for i in range (1,11):
        result = 1*n
    while

# %% [markdown]
# ### One parameter use of return

# %%
def square():
    return x**2
def squarearea(r):
    return square(r)

# %%
def square(x):
    """
    This function calculates the square of a given number.
    Input: The number x to be squared
    Output: The square of the inpit number
    """
    return x**2

# %%
square(4)
# Out:
# 16

# %%
def area_of_rect(length, width):
    """
    This function calculates the area of a rectangle.
    Input  = two parameters
    Output = Area 
    """
    
    area = length * width
    print("The area of a rectangle is: " ,area)

# %%
area_of_rect(13,10)
# Out:
# 130
