# %% [markdown]
# # STRINGS AND FILES

# %%
string_1 = ("I just finished my test")
string_2 = ("'Oh no!'I may have missed the game")

# %%
print(string_1)
# Out:
# I just finished my test

# %%
print(string_2)
# Out:
# 'Oh no!'I may have missed the game

# %% [markdown]
# ### Indexing

# %%
string_1[0]
# Out:
# 'I'

# %%
string_1[2]
# Out:
# 'j'

# %%
print(string_1[4])
print("The fifth character of my string is", string_1[4])
# Out:
# s
# The fifth character of my string is s

# %%
print(string_1[-1])
print("The fifth character of my string is", string_1[-1])
# Out:
# t
# The fifth character of my string is t

# %% [markdown]
# ### Slicing
#
# ```python
#     string[start:stop:step]
#
# ```

# %%
print(string_1)
string_1[2:8:2]
# Out:
# I just finished my test
# 'js '

# %%
string_3 = "DRETTVSHUKAVGGYYSGVEFFS"
string_3[2:8:2]
# Out:
# 'ETS'

# %%
string_3[2:8:]
# Out:
# 'ETTVSH'

# %%
string_3[::]
# Out:
# 'DRETTVSHUKAVGGYYSGVEFFS'

# %%
string_3[:]
# Out:
# 'DRETTVSHUKAVGGYYSGVEFFS'

# %%
string_3[:2]
# Out:
# 'DR'

# %%
string_3[1::2]
# Out:
# 'RTVHKVGYGEF'

# %%
len(string_3)
# Out:
# 23

# %% [markdown]
# ### Concatenation

# %%
var_1 = "Hey "
var_2 = "Bye"

concat = var_1 + var_2
concat2 = var_2 + var_1 
print(concat)
print(concat2)
# Out:
# Hey Bye
# ByeHey

# %%
print(2 * var_2)
# Out:
# ByeBye

# %%
print(2.5 * var_2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2512\1103646948.py in <module>
# ----> 1 print(2.5 *var_2)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
currency = "  Shilings is Kenya's currency"

# %%
# ?currency.casefold

# %%
currency.casefold()
# Out:
# "shilings is kenya's currency"

# %%
# ?currency.count

# %%
currency.count("i")
# Out:
# 3

# %%
# ?currency.capitalize

# %%
currency.capitalize()
# Out:
# "Shilings is kenya's currency"

# %%
# ?currency.title

# %%
currency.title()
# Out:
# "Shilings Is Kenya'S Currency"

# %%
# ?currency.strip

# %%
currency.strip()
# Out:
# "Shilings is Kenya's currency"

# %%
help(currency.format)
# Out:
# Help on built-in function format:
#
# format(...) method of builtins.str instance
#     S.format(*args, **kwargs) -> str
#
#     Return a formatted version of S, using substitutions from args and kwargs.
#     The substitutions are identified by braces ('{' and '}').

# %%
a, b = 1, 2
'fccgv {} ctuctv, {}'.format(a, b)
# Out:
# 'fccgv 1 ctuctv, 2'

# %%
help(currency.endswith)
# Out:
# Help on built-in function endswith:
#
# endswith(...) method of builtins.str instance
#     S.endswith(suffix[, start[, end]]) -> bool
#
#     Return True if S ends with the specified suffix, False otherwise.
#     With optional start, test S beginning at that position.
#     With optional end, stop comparing S at that position.
#     suffix can also be a tuple of strings to try.

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2853-0817
#
#  Directory of C:\Users\user\Desktop\python_course\notebooks_lecture_notes
#
# 09/25/2025  12:28 PM    <DIR>          .
# 09/25/2025  12:28 PM    <DIR>          ..
# 09/25/2025  12:28 PM    <DIR>          .ipynb_checkpoints
# 09/23/2025  10:34 AM             6,021 command_mode.png
# 09/24/2025  04:53 PM            70,939 deborah.aunga-day02-report.ipynb
# 09/23/2025  05:38 PM            59,822 deborahaunga-day00-report.ipynb
# 09/24/2025  06:49 PM            65,813 deborahaunga-day01-report.ipynb
# 09/25/2025  12:28 PM            16,180 deborah_aunga_day03.ipynb
# 09/25/2025  12:27 PM             1,787 deborah_aunga_day03.py
# 09/24/2025  10:25 PM            34,736 deborah_aunga_PP1.ipynb
# 09/23/2025  10:34 AM             6,030 edit_mode.png
# 09/23/2025  10:34 AM           194,094 Emily.png
# 09/23/2025  10:34 AM            17,311 menubar_toolbar.png
# ...

# %%
! ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
with open ("testfile.txt", 'r') as file:
    for lines in file:
        print(lines)
# Out:
# fghij
#
# aims class
#
# Rwanda 2025
#
# this is really cool

# %%
f = open("testfile.txt", "r")

# %%
type(f)
# Out:
# _io.TextIOWrapper

# %%
f.read()
# Out:
# 'fghij\naims class\nRwanda 2025\nthis is really cool'

# %%
f.read()
# Out:
# ''

# %%
to_write = open("outfile.txt","w")
to_write.write ("Today is Thursday \n")
to_write.write("Today is Wednesday")
to_write.close()

# %%
to_write = open("outfile.txt", "r")
to_write.readlines()
# Out:
# ['Today is Thursday \n', 'Today is Wednesday']

# %%
to_write_to_file= open("testfile.txt","w")
to_write_to_file.write ("Today is Thursday \n")
to_write_to_file.close()

# %%
help(f.readline)
# Out:
# Help on built-in function readline:
#
# readline(size=-1, /) method of _io.TextIOWrapper instance
#     Read until newline or EOF.
#
#     Returns an empty string if EOF is hit immediately.

# %%
f.readline(2)
# Out:
# ''

# %%
help(f.truncate)
# Out:
# Help on built-in function truncate:
#
# truncate(pos=None, /) method of _io.TextIOWrapper instance
#     Truncate file to size bytes.
#
#     File pointer is left unchanged.  Size defaults to the current IO
#     position as reported by tell().  Returns the new size.

# %%
with open("example.txt", "w+") as f:
    f.write("Hello, World!")
    f.truncate(5)

# %%
help(f.newlines)
# Out:
# Help on NoneType object:
#
# class NoneType(object)
#  |  Methods defined here:
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
help(f.writelines)
# Out:
# Help on built-in function writelines:
#
# writelines(lines, /) method of _io.TextIOWrapper instance
#     Write a list of lines to stream.
#
#     Line separators are not added, so it is usual for each of the
#     lines provided to have a line separator at the end.

# %%
lines = ["Hello there\n", "Salaam Aleikum\n", "Bonjourno\n"]

with open("notes.txt", "w") as f:
    f.writelines(lines)

# %%
with open("example.txt", "a") as f:
    f.writelines([
        "This school just comes with something new everyday to destroy me\n",
        "It's just month 1\n"
    ])
